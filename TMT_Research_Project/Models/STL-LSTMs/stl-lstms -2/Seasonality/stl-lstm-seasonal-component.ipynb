# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/individual-seasonal-trend-residual-dataframes/df_residual.csv
# /kaggle/input/individual-seasonal-trend-residual-dataframes/df_trend.csv
# /kaggle/input/individual-seasonal-trend-residual-dataframes/df_seasonal.csv

# %%
# !pip install feature-engine
# Out:
# Collecting feature-engine
#   Downloading feature_engine-1.8.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from feature-engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from feature-engine) (2.2.2)
# Collecting scikit-learn>=1.4.0 (from feature-engine)
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from feature-engine) (1.14.0)
# Requirement already satisfied: statsmodels>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from feature-engine) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.2.0->feature-engine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.2.0->feature-engine) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.4.0->feature-engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.11.1->feature-engine) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature-engine) (3.1.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Downloading feature_engine-1.8.1-py2.py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.1/364.1 kB 13.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 84.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: scikit-learn, feature-engine
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.8.2 which is incompatible.
# spaghetti 1.7.6 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.1 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed feature-engine-1.8.1 scikit-learn-1.5.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import random
#import shap
import optuna
import joblib
#!pip install openpyxl
from feature_engine.timeseries.forecasting import LagFeatures
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
# from pytorch_lightning.callbacks.early_stopping import EarlyStopping

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    if y_true.ndim > 1:
        y_true = y_true.flatten()  # Flatten if y_true is 2-dimensional
    if y_pred.ndim > 1:
        y_pred = y_pred.flatten()  # Flatten if y_pred is 2-dimensional

    non_zero_mask = (y_true != 0) & (y_pred != 0)  # Exclude zero values from calculation
    y_true = y_true[non_zero_mask]
    y_pred = y_pred[non_zero_mask]

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100 if len(y_true) != 0 else np.nan

# %%
df = pd.read_csv('/kaggle/input/individual-seasonal-trend-residual-dataframes/df_seasonal.csv')
df
# Out:
#                  Date_Time  Is_Holiday  Holiday_Type  OneHourSlot  Month  \
# 0      2019-01-01 00:00:00           0             0            1      1
# 1      2019-01-01 01:00:00           0             0            2      1
# 2      2019-01-01 02:00:00           0             0            3      1
# 3      2019-01-01 03:00:00           0             0            4      1
# 4      2019-01-01 04:00:00           0             0            5      1
# ...                    ...         ...           ...          ...    ...
# 46459  2024-04-19 19:00:00           0             0           20      4
# 46460  2024-04-19 20:00:00           0             0           21      4
# 46461  2024-04-19 21:00:00           0             0           22      4
# 46462  2024-04-19 22:00:00           0             0           23      4
# 46463  2024-04-19 23:00:00           0             0           24      4
#
#        Year  Weekday   Seasonal
# 0      2019        1 -62.946317
# 1      2019        1 -72.182077
# 2      2019        1 -73.449614
# 3      2019        1 -73.517630
# 4      2019        1 -67.510447
# ...     ...      ...        ...
# 46459  2024        4 -13.215410
# 46460  2024        4  24.998571
# 46461  2024        4 -22.917023
# 46462  2024        4 -18.455391
# 46463  2024        4 -24.138317
#
# [46464 rows x 8 columns]

# %%
df['Date_Time'] = pd.to_datetime(df['Date_Time'], format='%Y-%m-%d %H:%M:%S')
#df.drop(columns='OneHourSlot',inplace=True)
#df['hour'] = df['Date_Time'].dt.hour
df
# Out:
#                 Date_Time  Is_Holiday  Holiday_Type  OneHourSlot  Month  Year  \
# 0     2019-01-01 00:00:00           0             0            1      1  2019
# 1     2019-01-01 01:00:00           0             0            2      1  2019
# 2     2019-01-01 02:00:00           0             0            3      1  2019
# 3     2019-01-01 03:00:00           0             0            4      1  2019
# 4     2019-01-01 04:00:00           0             0            5      1  2019
# ...                   ...         ...           ...          ...    ...   ...
# 46459 2024-04-19 19:00:00           0             0           20      4  2024
# 46460 2024-04-19 20:00:00           0             0           21      4  2024
# 46461 2024-04-19 21:00:00           0             0           22      4  2024
# 46462 2024-04-19 22:00:00           0             0           23      4  2024
# 46463 2024-04-19 23:00:00           0             0           24      4  2024
#
#        Weekday   Seasonal
# 0            1 -62.946317
# 1            1 -72.182077
# 2            1 -73.449614
# 3            1 -73.517630
# 4            1 -67.510447
# ...        ...        ...
# 46459        4 -13.215410
# 46460        4  24.998571
# 46461        4 -22.917023
# 46462        4 -18.455391
# 46463        4 -24.138317
#
# [46464 rows x 8 columns]

# %%
df.drop(columns='OneHourSlot', inplace=True)

# %%
df.head(3)
# Out:
#             Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0 2019-01-01 00:00:00           0             0      1  2019        1
# 1 2019-01-01 01:00:00           0             0      1  2019        1
# 2 2019-01-01 02:00:00           0             0      1  2019        1
#
#     Seasonal
# 0 -62.946317
# 1 -72.182077
# 2 -73.449614

# %% [markdown]
# # filtering out the df from 1st Jan 2019 to 20th April 2024

# %%
# Define start and end dates
start_date = pd.Timestamp(2019, 1, 1)
end_date = pd.Timestamp(2024, 4, 20)

# Filter the DataFrame
df = df[(df['Date_Time'] >= start_date) & (df['Date_Time'] < end_date)]
df
# Out:
#                 Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0     2019-01-01 00:00:00           0             0      1  2019        1
# 1     2019-01-01 01:00:00           0             0      1  2019        1
# 2     2019-01-01 02:00:00           0             0      1  2019        1
# 3     2019-01-01 03:00:00           0             0      1  2019        1
# 4     2019-01-01 04:00:00           0             0      1  2019        1
# ...                   ...         ...           ...    ...   ...      ...
# 46459 2024-04-19 19:00:00           0             0      4  2024        4
# 46460 2024-04-19 20:00:00           0             0      4  2024        4
# 46461 2024-04-19 21:00:00           0             0      4  2024        4
# 46462 2024-04-19 22:00:00           0             0      4  2024        4
# 46463 2024-04-19 23:00:00           0             0      4  2024        4
#
#         Seasonal
# 0     -62.946317
# 1     -72.182077
# 2     -73.449614
# 3     -73.517630
# 4     -67.510447
# ...          ...
# 46459 -13.215410
# 46460  24.998571
# 46461 -22.917023
# 46462 -18.455391
# 46463 -24.138317
#
# [46464 rows x 7 columns]

# %%
sp = 'Voltas_Gate_Thane_Station_West'

# %%
# Setting seeds for random number generators in different libraries ensures reproducibility of results.

random.seed(100)
np.random.seed(100)
tf.random.set_seed(100)

# %%
# Plotting the graph
plt.figure(figsize=(10, 3))  # Set the width and height of the figure
plt.plot(df['Date_Time'].to_numpy(), df['Seasonal'].to_numpy(), color='blue')
plt.title(f"Seasonality Component")
plt.xlabel('Date Time')  # X-axis label
plt.ylabel('Seasonality')  # Y-axis label
plt.tick_params('x', labelrotation=45)  # Rotate x-axis labels by 45 degrees
plt.show()

# %%
df['Seasonal'].to_numpy()
# Out:
# array([-62.94631734, -72.18207737, -73.44961361, ..., -22.91702318,
#        -18.45539101, -24.13831737])

# %%
#df.loc[df['Seasonal'] < 0, 'Seasonal'] = 0

# %%
df['Seasonal']
# Out:
# 0       -62.946317
# 1       -72.182077
# 2       -73.449614
# 3       -73.517630
# 4       -67.510447
#            ...
# 46459   -13.215410
# 46460    24.998571
# 46461   -22.917023
# 46462   -18.455391
# 46463   -24.138317
# Name: Seasonal, Length: 46464, dtype: float64

# %%
df
# Out:
#                 Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0     2019-01-01 00:00:00           0             0      1  2019        1
# 1     2019-01-01 01:00:00           0             0      1  2019        1
# 2     2019-01-01 02:00:00           0             0      1  2019        1
# 3     2019-01-01 03:00:00           0             0      1  2019        1
# 4     2019-01-01 04:00:00           0             0      1  2019        1
# ...                   ...         ...           ...    ...   ...      ...
# 46459 2024-04-19 19:00:00           0             0      4  2024        4
# 46460 2024-04-19 20:00:00           0             0      4  2024        4
# 46461 2024-04-19 21:00:00           0             0      4  2024        4
# 46462 2024-04-19 22:00:00           0             0      4  2024        4
# 46463 2024-04-19 23:00:00           0             0      4  2024        4
#
#         Seasonal
# 0     -62.946317
# 1     -72.182077
# 2     -73.449614
# 3     -73.517630
# 4     -67.510447
# ...          ...
# 46459 -13.215410
# 46460  24.998571
# 46461 -22.917023
# 46462 -18.455391
# 46463 -24.138317
#
# [46464 rows x 7 columns]

# %%
df.to_csv('input_file_1.csv', index=False)
print("this file contains : ", df.head(3))
# Out:
# this file contains :              Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0 2019-01-01 00:00:00           0             0      1  2019        1
# 1 2019-01-01 01:00:00           0             0      1  2019        1
# 2 2019-01-01 02:00:00           0             0      1  2019        1
#
#     Seasonal
# 0 -62.946317
# 1 -72.182077
# 2 -73.449614

# %%
# create lag features

lag_transformer = LagFeatures(variables=['Seasonal'], periods=[1,2,24,24*7,24*14,24*21,24*28])
df = lag_transformer.fit_transform(df)

# %%
df.head()
# Out:
#             Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0 2019-01-01 00:00:00           0             0      1  2019        1
# 1 2019-01-01 01:00:00           0             0      1  2019        1
# 2 2019-01-01 02:00:00           0             0      1  2019        1
# 3 2019-01-01 03:00:00           0             0      1  2019        1
# 4 2019-01-01 04:00:00           0             0      1  2019        1
#
#     Seasonal  Seasonal_lag_1  Seasonal_lag_2  Seasonal_lag_24  \
# 0 -62.946317             NaN             NaN              NaN
# 1 -72.182077      -62.946317             NaN              NaN
# 2 -73.449614      -72.182077      -62.946317              NaN
# 3 -73.517630      -73.449614      -72.182077              NaN
# 4 -67.510447      -73.517630      -73.449614              NaN
#
#    Seasonal_lag_168  Seasonal_lag_336  Seasonal_lag_504  Seasonal_lag_672
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN

# %%
df.tail()
# Out:
#                 Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 46459 2024-04-19 19:00:00           0             0      4  2024        4
# 46460 2024-04-19 20:00:00           0             0      4  2024        4
# 46461 2024-04-19 21:00:00           0             0      4  2024        4
# 46462 2024-04-19 22:00:00           0             0      4  2024        4
# 46463 2024-04-19 23:00:00           0             0      4  2024        4
#
#         Seasonal  Seasonal_lag_1  Seasonal_lag_2  Seasonal_lag_24  \
# 46459 -13.215410        3.135115       26.843958       -11.486903
# 46460  24.998571      -13.215410        3.135115        24.160515
# 46461 -22.917023       24.998571      -13.215410       -23.116244
# 46462 -18.455391      -22.917023       24.998571       -19.667309
# 46463 -24.138317      -18.455391      -22.917023       -23.596726
#
#        Seasonal_lag_168  Seasonal_lag_336  Seasonal_lag_504  Seasonal_lag_672
# 46459         -1.718593         10.341876         18.431855         22.763349
# 46460         18.796946         15.932651          7.417508          4.404355
# 46461        -23.451170        -22.175281        -21.882550        -21.805520
# 46462        -27.486975        -35.011246        -31.377569        -24.176137
# 46463        -20.591160        -20.981346        -29.102374        -30.969258

# %%
df.to_csv('input_file_2.csv', index=False)
print(df.head(3))
# Out:
#             Date_Time  Is_Holiday  Holiday_Type  Month  Year  Weekday  \
# 0 2019-01-01 00:00:00           0             0      1  2019        1
# 1 2019-01-01 01:00:00           0             0      1  2019        1
# 2 2019-01-01 02:00:00           0             0      1  2019        1
#
#     Seasonal  Seasonal_lag_1  Seasonal_lag_2  Seasonal_lag_24  \
# 0 -62.946317             NaN             NaN              NaN
# 1 -72.182077      -62.946317             NaN              NaN
# 2 -73.449614      -72.182077      -62.946317              NaN
#
#    Seasonal_lag_168  Seasonal_lag_336  Seasonal_lag_504  Seasonal_lag_672
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN

# %%
# create X & y for modelling (Feature Matrix X and Y )

df = df.dropna()
X = df.drop(columns=['Date_Time','Seasonal']) # Feature Matrix X
y = df['Seasonal'] # Target Variable

# %%
X
# Out:
#        Is_Holiday  Holiday_Type  Month  Year  Weekday  Seasonal_lag_1  \
# 672             0             0      1  2019        1      -45.124924
# 673             0             0      1  2019        1      -63.708124
# 674             0             0      1  2019        1      -70.750910
# 675             0             0      1  2019        1      -71.203272
# 676             0             0      1  2019        1      -71.204769
# ...           ...           ...    ...   ...      ...             ...
# 46459           0             0      4  2024        4        3.135115
# 46460           0             0      4  2024        4      -13.215410
# 46461           0             0      4  2024        4       24.998571
# 46462           0             0      4  2024        4      -22.917023
# 46463           0             0      4  2024        4      -18.455391
#
#        Seasonal_lag_2  Seasonal_lag_24  Seasonal_lag_168  Seasonal_lag_336  \
# 672        -42.579945       -63.686455        -64.934960        -66.262929
# 673        -45.124924       -70.778905        -72.394609        -74.098984
# 674        -63.708124       -71.238425        -72.954441        -74.737855
# 675        -70.750910       -71.236869        -72.940186        -74.733035
# 676        -71.203272       -67.898137        -69.263391        -70.243634
# ...               ...              ...               ...               ...
# 46459       26.843958       -11.486903         -1.718593         10.341876
# 46460        3.135115        24.160515         18.796946         15.932651
# 46461      -13.215410       -23.116244        -23.451170        -22.175281
# 46462       24.998571       -19.667309        -27.486975        -35.011246
# 46463      -22.917023       -23.596726        -20.591160        -20.981346
#
#        Seasonal_lag_504  Seasonal_lag_672
# 672          -64.998123        -62.946317
# 673          -73.500706        -72.182077
# 674          -74.295151        -73.449614
# 675          -74.311972        -73.517630
# 676          -69.075519        -67.510447
# ...                 ...               ...
# 46459         18.431855         22.763349
# 46460          7.417508          4.404355
# 46461        -21.882550        -21.805520
# 46462        -31.377569        -24.176137
# 46463        -29.102374        -30.969258
#
# [45792 rows x 12 columns]

# %%
y
# Out:
# 672     -63.708124
# 673     -70.750910
# 674     -71.203272
# 675     -71.204769
# 676     -67.921373
#            ...
# 46459   -13.215410
# 46460    24.998571
# 46461   -22.917023
# 46462   -18.455391
# 46463   -24.138317
# Name: Seasonal, Length: 45792, dtype: float64

# %%
# split into train & test

X_train = X.iloc[:int(np.round((0.95*len(X)))),:]
X_test = X.iloc[int(np.round((0.95*len(X)))):,:]
y_train = y[:int(np.round((0.95*len(X))))]
y_test = y[int(np.round((0.95*len(X)))):]

# %%
X_train
# Out:
#        Is_Holiday  Holiday_Type  Month  Year  Weekday  Seasonal_lag_1  \
# 672             0             0      1  2019        1      -45.124924
# 673             0             0      1  2019        1      -63.708124
# 674             0             0      1  2019        1      -70.750910
# 675             0             0      1  2019        1      -71.203272
# 676             0             0      1  2019        1      -71.204769
# ...           ...           ...    ...   ...      ...             ...
# 44169           0             0      1  2024        0      127.995631
# 44170           0             0      1  2024        0       75.523973
# 44171           0             0      1  2024        0       39.607856
# 44172           0             0      1  2024        0        1.952916
# 44173           0             0      1  2024        0        7.376839
#
#        Seasonal_lag_2  Seasonal_lag_24  Seasonal_lag_168  Seasonal_lag_336  \
# 672        -42.579945       -63.686455        -64.934960        -66.262929
# 673        -45.124924       -70.778905        -72.394609        -74.098984
# 674        -63.708124       -71.238425        -72.954441        -74.737855
# 675        -70.750910       -71.236869        -72.940186        -74.733035
# 676        -71.203272       -67.898137        -69.263391        -70.243634
# ...               ...              ...               ...               ...
# 44169       42.605070        76.142519         79.479178         82.166545
# 44170      127.995631        39.028225         32.097777         29.360329
# 44171       75.523973         2.702428          5.594347          4.665019
# 44172       39.607856         7.173545          8.544849         14.533242
# 44173        1.952916        -3.610666         -5.752711         -9.860893
#
#        Seasonal_lag_504  Seasonal_lag_672
# 672          -64.998123        -62.946317
# 673          -73.500706        -72.182077
# 674          -74.295151        -73.449614
# 675          -74.311972        -73.517630
# 676          -69.075519        -67.510447
# ...                 ...               ...
# 44169         81.182570         80.004886
# 44170         31.603537         30.731380
# 44171          1.963551          4.374845
# 44172         10.613765         12.348118
# 44173         -6.654339         -1.794617
#
# [43502 rows x 12 columns]

# %%
y_train
# Out:
# 672     -63.708124
# 673     -70.750910
# 674     -71.203272
# 675     -71.204769
# 676     -67.921373
#            ...
# 44169    75.523973
# 44170    39.607856
# 44171     1.952916
# 44172     7.376839
# 44173    -4.545468
# Name: Seasonal, Length: 43502, dtype: float64

# %%
X_test
# Out:
#        Is_Holiday  Holiday_Type  Month  Year  Weekday  Seasonal_lag_1  \
# 44174           0             0      1  2024        0       -4.545468
# 44175           0             0      1  2024        0      -15.345555
# 44176           0             0      1  2024        0      -12.517402
# 44177           0             0      1  2024        0        8.055435
# 44178           0             0      1  2024        0       26.185095
# ...           ...           ...    ...   ...      ...             ...
# 46459           0             0      4  2024        4        3.135115
# 46460           0             0      4  2024        4      -13.215410
# 46461           0             0      4  2024        4       24.998571
# 46462           0             0      4  2024        4      -22.917023
# 46463           0             0      4  2024        4      -18.455391
#
#        Seasonal_lag_2  Seasonal_lag_24  Seasonal_lag_168  Seasonal_lag_336  \
# 44174        7.376839       -14.177162         -7.676756        -12.389024
# 44175       -4.545468       -12.079453         -8.181413         -9.862314
# 44176      -15.345555         7.402521          3.757941          7.577407
# 44177      -12.517402        27.716317         41.129677         51.670965
# 44178        8.055435        22.659688         15.325175          5.156377
# ...               ...              ...               ...               ...
# 46459       26.843958       -11.486903         -1.718593         10.341876
# 46460        3.135115        24.160515         18.796946         15.932651
# 46461      -13.215410       -23.116244        -23.451170        -22.175281
# 46462       24.998571       -19.667309        -27.486975        -35.011246
# 46463      -22.917023       -23.596726        -20.591160        -20.981346
#
#        Seasonal_lag_504  Seasonal_lag_672
# 44174        -14.499080        -13.187352
# 44175        -13.588778        -13.664244
# 44176          4.429986         -2.541553
# 44177         45.790227         48.992196
# 44178          8.948433         15.131969
# ...                 ...               ...
# 46459         18.431855         22.763349
# 46460          7.417508          4.404355
# 46461        -21.882550        -21.805520
# 46462        -31.377569        -24.176137
# 46463        -29.102374        -30.969258
#
# [2290 rows x 12 columns]

# %%
y_test
# Out:
# 44174   -15.345555
# 44175   -12.517402
# 44176     8.055435
# 44177    26.185095
# 44178    24.372202
#            ...
# 46459   -13.215410
# 46460    24.998571
# 46461   -22.917023
# 46462   -18.455391
# 46463   -24.138317
# Name: Seasonal, Length: 2290, dtype: float64

# %%
sc_X = MinMaxScaler(feature_range = (0, 1))
X_train_scaled = sc_X.fit_transform(X_train)
X_train_scaled_2 = np.reshape(X_train_scaled,(X_train_scaled.shape[0],X_train_scaled.shape[1],1))
joblib.dump(sc_X, f'/kaggle/working/scaler_X_{sp}.joblib')

sc_y = MinMaxScaler(feature_range = (0, 1))
y_train_scaled = sc_y.fit_transform(np.reshape(y_train,(len(y_train),1)))
joblib.dump(sc_y, f'/kaggle/working/scaler_y_{sp}.joblib')
# Out:
# ['/kaggle/working/scaler_y_Voltas_Gate_Thane_Station_West.joblib']

# %%
sc_X
# Out:
# MinMaxScaler()

# %%
sc_y
# Out:
# MinMaxScaler()

# %%
# normalizing test set & reshape

X_test_scaled = sc_X.transform(X_test)
X_test_scaled_2 = np.reshape(X_test_scaled,(X_test_scaled.shape[0],X_test_scaled.shape[1],1))

path_best_model = f"/kaggle/working/{sp}.keras"
best_loss = 100

# %%
X_test_scaled
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.26237981, 0.25354422,
#         0.25906397],
#        [0.        , 0.        , 0.        , ..., 0.27301285, 0.25737477,
#         0.25705721],
#        [0.        , 0.        , 0.        , ..., 0.34640366, 0.33319786,
#         0.30386157],
#        ...,
#        [0.        , 0.        , 0.27272727, ..., 0.22119674, 0.22247452,
#         0.22279867],
#        [0.        , 0.        , 0.27272727, ..., 0.16717972, 0.18251941,
#         0.21282309],
#        [0.        , 0.        , 0.27272727, ..., 0.22622112, 0.19209345,
#         0.18423759]])

# %%
def objective(trial):
    es = EarlyStopping(patience=5)

    # Adding 1st LSTM Layer
    regressor = Sequential() # kerasnsequential model 
    regressor.add(LSTM(units=trial.suggest_int('lstm', 2, 512), return_sequences=True, input_shape=(X_train.shape[1], 1)))
    regressor.add(Dropout(trial.suggest_categorical('dropout', [0.1, 0.2, 0.4, 0.6, 0.8])))

    # Adding 2nd LSTM layer
    regressor.add(LSTM(units=trial.suggest_int('lstm_2', 2, 512), return_sequences=False))

    # Output layer
    regressor.add(Dense(units=1)) # single dense layer with single unit 

    regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
    history = regressor.fit(X_train_scaled_2, y_train_scaled,  batch_size= trial.suggest_int('bs',32,512), epochs = 200,validation_split=0.1, callbacks=[es],shuffle=False)

    loss = history.history['val_loss'][-1]
    global best_loss
    if loss < best_loss:
        regressor.save(path_best_model)
        best_loss = loss
    del regressor
    return loss

study = optuna.create_study(
direction='minimize',
load_if_exists=True)
study.optimize(objective, n_trials=5)
# Out:
# [I 2024-09-14 06:53:41,404] A new study created in memory with name: no-name-45bff328-4eed-497d-800d-5113236a88ca
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0215 - val_loss: 0.0014
# Epoch 2/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 9.1137e-04
# Epoch 3/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 9.2461e-04
# Epoch 4/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 8.9287e-04
# Epoch 5/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 9.0622e-04
# Epoch 6/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - val_loss: 8.9363e-04
# Epoch 7/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9718e-04 - val_loss: 8.7904e-04
# Epoch 8/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7787e-04 - val_loss: 8.5052e-04
# Epoch 9/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.0101e-04 - val_loss: 8.4294e-04
# Epoch 10/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7988e-04 - val_loss: 8.4487e-04
# Epoch 11/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6942e-04 - val_loss: 8.4924e-04
# Epoch 12/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.4479e-04 - val_loss: 0.0010
# Epoch 13/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8792e-04 - val_loss: 9.6801e-04
# Epoch 14/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7682e-04 - val_loss: 7.7973e-04
# Epoch 15/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8555e-04 - val_loss: 8.3365e-04
# Epoch 16/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6672e-04 - val_loss: 8.2072e-04
# Epoch 17/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1632e-04 - val_loss: 7.9320e-04
# Epoch 18/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.6872e-04 - val_loss: 7.2668e-04
# Epoch 19/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9378e-04 - val_loss: 7.0413e-04
# Epoch 20/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1185e-04 - val_loss: 6.8201e-04
# Epoch 21/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8565e-04 - val_loss: 6.6390e-04
# Epoch 22/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7305e-04 - val_loss: 7.1914e-04
# Epoch 23/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.5414e-04 - val_loss: 6.5670e-04
# Epoch 24/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1493e-04 - val_loss: 6.9628e-04
# Epoch 25/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7053e-04 - val_loss: 6.2085e-04
# Epoch 26/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1116e-04 - val_loss: 5.9623e-04
# Epoch 27/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9177e-04 - val_loss: 6.0605e-04
# Epoch 28/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.2396e-04 - val_loss: 6.1738e-04
# Epoch 29/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1938e-04 - val_loss: 6.2098e-04
# Epoch 30/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.3039e-04 - val_loss: 6.1275e-04
# Epoch 31/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9492e-04 - val_loss: 5.8604e-04
# Epoch 32/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2548e-04 - val_loss: 6.1464e-04
# Epoch 33/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7435e-04 - val_loss: 6.4527e-04
# Epoch 34/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9822e-04 - val_loss: 5.5757e-04
# Epoch 35/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.0196e-04 - val_loss: 5.6806e-04
# Epoch 36/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6133e-04 - val_loss: 5.4972e-04
# Epoch 37/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5540e-04 - val_loss: 5.6930e-04
# Epoch 38/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4836e-04 - val_loss: 5.4829e-04
# Epoch 39/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4389e-04 - val_loss: 5.2270e-04
# Epoch 40/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5110e-04 - val_loss: 5.2036e-04
# Epoch 41/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3012e-04 - val_loss: 5.2744e-04
# Epoch 42/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0963e-04 - val_loss: 4.9753e-04
# Epoch 43/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2803e-04 - val_loss: 5.7355e-04
# Epoch 44/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6199e-04 - val_loss: 5.5249e-04
# Epoch 45/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.8744e-04 - val_loss: 6.1078e-04
# Epoch 46/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5137e-04 - val_loss: 4.9159e-04
# Epoch 47/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0041e-04 - val_loss: 4.4372e-04
# Epoch 48/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8574e-04 - val_loss: 5.1816e-04
# Epoch 49/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9484e-04 - val_loss: 4.1194e-04
# Epoch 50/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9525e-04 - val_loss: 4.1207e-04
# Epoch 51/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9444e-04 - val_loss: 5.3402e-04
# Epoch 52/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.1530e-04 - val_loss: 4.1846e-04
# Epoch 53/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6192e-04 - val_loss: 3.9934e-04
# Epoch 54/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8319e-04 - val_loss: 4.7612e-04
# Epoch 55/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9581e-04 - val_loss: 4.4805e-04
# Epoch 56/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5775e-04 - val_loss: 4.5012e-04
# Epoch 57/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8990e-04 - val_loss: 4.1955e-04
# Epoch 58/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4808e-04 - val_loss: 4.0828e-04
# [I 2024-09-14 06:54:50,186] Trial 0 finished with value: 0.00040828375495038927 and parameters: {'lstm': 109, 'dropout': 0.8, 'lstm_2': 332, 'bs': 409}. Best is trial 0 with value: 0.00040828375495038927.
# Epoch 1/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0074 - val_loss: 9.5453e-04
# Epoch 2/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 7.1348e-04 - val_loss: 0.0011
# Epoch 3/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 6.8194e-04 - val_loss: 9.6655e-04
# Epoch 4/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 6.7261e-04 - val_loss: 8.4698e-04
# Epoch 5/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 6.5294e-04 - val_loss: 9.2689e-04
# Epoch 6/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 5.4151e-04 - val_loss: 4.8302e-04
# Epoch 7/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 4.6845e-04 - val_loss: 5.6787e-04
# Epoch 8/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 4.3702e-04 - val_loss: 5.8574e-04
# Epoch 9/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 4.0192e-04 - val_loss: 3.3114e-04
# Epoch 10/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3.4922e-04 - val_loss: 3.2750e-04
# Epoch 11/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3.5560e-04 - val_loss: 3.0640e-04
# Epoch 12/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3.1922e-04 - val_loss: 2.4297e-04
# Epoch 13/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.7348e-04 - val_loss: 2.3920e-04
# Epoch 14/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.6708e-04 - val_loss: 2.9297e-04
# Epoch 15/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.5399e-04 - val_loss: 2.4336e-04
# Epoch 16/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.3069e-04 - val_loss: 2.4845e-04
# Epoch 17/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.4099e-04 - val_loss: 1.8989e-04
# Epoch 18/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.4674e-04 - val_loss: 1.9755e-04
# Epoch 19/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.2810e-04 - val_loss: 2.0759e-04
# Epoch 20/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.2432e-04 - val_loss: 2.5053e-04
# Epoch 21/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.2608e-04 - val_loss: 2.1742e-04
# Epoch 22/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2.2550e-04 - val_loss: 2.2609e-04
# [I 2024-09-14 06:56:12,500] Trial 1 finished with value: 0.0002260926557937637 and parameters: {'lstm': 293, 'dropout': 0.4, 'lstm_2': 482, 'bs': 114}. Best is trial 1 with value: 0.0002260926557937637.
# Epoch 1/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0212 - val_loss: 0.0012
# Epoch 2/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8279e-04 - val_loss: 0.0010
# Epoch 3/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0549e-04 - val_loss: 0.0010
# Epoch 4/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.1621e-04 - val_loss: 9.2556e-04
# Epoch 5/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5193e-04 - val_loss: 9.8490e-04
# Epoch 6/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4146e-04 - val_loss: 9.4100e-04
# Epoch 7/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9250e-04 - val_loss: 9.0612e-04
# Epoch 8/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6848e-04 - val_loss: 8.7428e-04
# Epoch 9/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4177e-04 - val_loss: 8.3615e-04
# Epoch 10/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2846e-04 - val_loss: 8.0212e-04
# Epoch 11/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4161e-04 - val_loss: 8.0086e-04
# Epoch 12/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8491e-04 - val_loss: 7.8415e-04
# Epoch 13/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6774e-04 - val_loss: 9.1317e-04
# Epoch 14/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1459e-04 - val_loss: 8.9665e-04
# Epoch 15/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1553e-04 - val_loss: 9.6280e-04
# Epoch 16/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1934e-04 - val_loss: 9.4480e-04
# Epoch 17/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1436e-04 - val_loss: 0.0010
# [I 2024-09-14 06:56:30,985] Trial 2 finished with value: 0.0010293795494362712 and parameters: {'lstm': 266, 'dropout': 0.4, 'lstm_2': 104, 'bs': 462}. Best is trial 1 with value: 0.0002260926557937637.
# Epoch 1/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0196 - val_loss: 9.6541e-04
# Epoch 2/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.3969e-04 - val_loss: 9.6038e-04
# Epoch 3/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.5310e-04 - val_loss: 9.4354e-04
# Epoch 4/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.1328e-04 - val_loss: 9.1877e-04
# Epoch 5/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.9671e-04 - val_loss: 9.1997e-04
# Epoch 6/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.9282e-04 - val_loss: 8.9679e-04
# Epoch 7/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.6706e-04 - val_loss: 8.7559e-04
# Epoch 8/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.3312e-04 - val_loss: 8.6942e-04
# Epoch 9/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.2106e-04 - val_loss: 8.6681e-04
# Epoch 10/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.1901e-04 - val_loss: 8.4599e-04
# Epoch 11/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.2582e-04 - val_loss: 8.1934e-04
# Epoch 12/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.8501e-04 - val_loss: 8.5005e-04
# Epoch 13/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.4409e-04 - val_loss: 8.6202e-04
# Epoch 14/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.3860e-04 - val_loss: 8.4808e-04
# Epoch 15/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.2578e-04 - val_loss: 8.1546e-04
# Epoch 16/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.3130e-04 - val_loss: 7.8769e-04
# Epoch 17/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.9990e-04 - val_loss: 7.5513e-04
# Epoch 18/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.8906e-04 - val_loss: 7.8575e-04
# Epoch 19/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.2033e-04 - val_loss: 7.1735e-04
# Epoch 20/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.7121e-04 - val_loss: 7.5347e-04
# Epoch 21/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.1884e-04 - val_loss: 6.9598e-04
# Epoch 22/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.9133e-04 - val_loss: 6.4024e-04
# Epoch 23/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.6113e-04 - val_loss: 6.3526e-04
# Epoch 24/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.6198e-04 - val_loss: 5.7708e-04
# Epoch 25/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.3939e-04 - val_loss: 5.6401e-04
# Epoch 26/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.0188e-04 - val_loss: 6.1305e-04
# Epoch 27/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.8019e-04 - val_loss: 4.8623e-04
# Epoch 28/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 4.2908e-04 - val_loss: 4.2007e-04
# Epoch 29/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.3096e-04 - val_loss: 3.7501e-04
# Epoch 30/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.2071e-04 - val_loss: 3.6531e-04
# Epoch 31/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.2317e-04 - val_loss: 3.7244e-04
# Epoch 32/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.3714e-04 - val_loss: 4.3057e-04
# Epoch 33/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.8839e-04 - val_loss: 4.1387e-04
# Epoch 34/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 4.1162e-04 - val_loss: 3.3668e-04
# Epoch 35/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.7513e-04 - val_loss: 2.9384e-04
# Epoch 36/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.4707e-04 - val_loss: 3.0648e-04
# Epoch 37/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.8483e-04 - val_loss: 2.6935e-04
# Epoch 38/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.0556e-04 - val_loss: 2.7850e-04
# Epoch 39/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.9072e-04 - val_loss: 2.8534e-04
# Epoch 40/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7460e-04 - val_loss: 2.7002e-04
# Epoch 41/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.8071e-04 - val_loss: 2.7139e-04
# Epoch 42/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.6489e-04 - val_loss: 2.4390e-04
# Epoch 43/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.6104e-04 - val_loss: 2.7855e-04
# Epoch 44/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.3398e-04 - val_loss: 2.3510e-04
# Epoch 45/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5398e-04 - val_loss: 2.2980e-04
# Epoch 46/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.6079e-04 - val_loss: 2.2556e-04
# Epoch 47/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.2654e-04 - val_loss: 2.0539e-04
# Epoch 48/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.1395e-04 - val_loss: 1.9756e-04
# Epoch 49/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.0565e-04 - val_loss: 1.8244e-04
# Epoch 50/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.0382e-04 - val_loss: 2.2181e-04
# Epoch 51/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.3811e-04 - val_loss: 2.7998e-04
# Epoch 52/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.8574e-04 - val_loss: 2.1823e-04
# Epoch 53/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.7175e-04 - val_loss: 2.5824e-04
# Epoch 54/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.7942e-04 - val_loss: 1.5975e-04
# Epoch 55/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.5226e-04 - val_loss: 2.7506e-04
# Epoch 56/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.4860e-04 - val_loss: 1.3175e-04
# Epoch 57/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.3577e-04 - val_loss: 1.3100e-04
# Epoch 58/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7096e-04 - val_loss: 1.2161e-04
# Epoch 59/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 4.1502e-04 - val_loss: 1.1383e-04
# Epoch 60/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.3918e-04 - val_loss: 1.0462e-04
# Epoch 61/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.9024e-04 - val_loss: 1.0957e-04
# Epoch 62/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5416e-04 - val_loss: 1.0481e-04
# Epoch 63/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.6225e-04 - val_loss: 1.0720e-04
# Epoch 64/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5651e-04 - val_loss: 1.0871e-04
# Epoch 65/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.8492e-04 - val_loss: 1.0342e-04
# Epoch 66/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7788e-04 - val_loss: 1.0450e-04
# Epoch 67/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7154e-04 - val_loss: 1.1114e-04
# Epoch 68/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7754e-04 - val_loss: 9.8063e-05
# Epoch 69/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5091e-04 - val_loss: 1.0190e-04
# Epoch 70/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7354e-04 - val_loss: 9.8413e-05
# Epoch 71/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.4021e-04 - val_loss: 9.6570e-05
# Epoch 72/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7177e-04 - val_loss: 9.5709e-05
# Epoch 73/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.1914e-04 - val_loss: 9.8626e-05
# Epoch 74/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.8321e-04 - val_loss: 9.8373e-05
# Epoch 75/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5448e-04 - val_loss: 9.0929e-05
# Epoch 76/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.5369e-04 - val_loss: 8.9315e-05
# Epoch 77/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.4799e-04 - val_loss: 8.9178e-05
# Epoch 78/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.3625e-04 - val_loss: 9.1071e-05
# Epoch 79/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.2959e-04 - val_loss: 9.0675e-05
# Epoch 80/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.6899e-04 - val_loss: 9.7287e-05
# Epoch 81/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.2348e-04 - val_loss: 8.5938e-05
# Epoch 82/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.2007e-04 - val_loss: 9.2703e-05
# Epoch 83/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.0192e-04 - val_loss: 8.6217e-05
# Epoch 84/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.1153e-04 - val_loss: 9.3726e-05
# Epoch 85/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.1366e-04 - val_loss: 9.0008e-05
# Epoch 86/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.6822e-04 - val_loss: 9.7439e-05
# [I 2024-09-14 06:59:46,001] Trial 3 finished with value: 9.743927512317896e-05 and parameters: {'lstm': 418, 'dropout': 0.2, 'lstm_2': 320, 'bs': 495}. Best is trial 3 with value: 9.743927512317896e-05.
# Epoch 1/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0097 - val_loss: 9.1161e-04
# Epoch 2/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.9097e-04 - val_loss: 9.3921e-04
# Epoch 3/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.9562e-04 - val_loss: 9.7067e-04
# Epoch 4/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.8231e-04 - val_loss: 9.7449e-04
# Epoch 5/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.6441e-04 - val_loss: 9.2391e-04
# Epoch 6/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.5960e-04 - val_loss: 8.4746e-04
# Epoch 7/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.5258e-04 - val_loss: 7.7576e-04
# Epoch 8/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.5513e-04 - val_loss: 7.1487e-04
# Epoch 9/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.3617e-04 - val_loss: 6.6732e-04
# Epoch 10/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.1598e-04 - val_loss: 5.9958e-04
# Epoch 11/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0064e-04 - val_loss: 5.4130e-04
# Epoch 12/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.5827e-04 - val_loss: 5.3152e-04
# Epoch 13/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8759e-04 - val_loss: 4.0936e-04
# Epoch 14/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5203e-04 - val_loss: 2.9464e-04
# Epoch 15/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.0475e-04 - val_loss: 2.8002e-04
# Epoch 16/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.6045e-04 - val_loss: 3.5364e-04
# Epoch 17/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.7930e-04 - val_loss: 3.1062e-04
# Epoch 18/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.5564e-04 - val_loss: 3.1723e-04
# Epoch 19/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.5114e-04 - val_loss: 3.7165e-04
# Epoch 20/200
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.1552e-04 - val_loss: 3.9697e-04
# [I 2024-09-14 07:00:28,817] Trial 4 finished with value: 0.0003969706012867391 and parameters: {'lstm': 322, 'dropout': 0.1, 'lstm_2': 182, 'bs': 166}. Best is trial 3 with value: 9.743927512317896e-05.

# %%
# predict on test set

model = tf.keras.models.load_model(f'/kaggle/working/{sp}.keras')
pred_inverse = model.predict(X_test_scaled_2)
pred_2 = sc_y.inverse_transform(pred_inverse)
pred = np.floor(pred_2)
pred = np.where(pred<0, 0, pred)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
rmse=mean_squared_error(y_test,pred,squared=False)
rscore=r2_score(y_test,pred)
mape=mean_absolute_percentage_error(y_test,pred)
mae=mean_absolute_error(y_test,pred)
print('rmse:', mean_squared_error(y_test,pred,squared=False))
print('r2:', r2_score(y_test,pred))
print('mape:', mean_absolute_percentage_error(y_test,pred))
print('mae:', mean_absolute_error(y_test,pred))
# Out:
# rmse: 26.905060584278008
# r2: 0.6288683103061672
# mape: 18.452511003337875
# mae: 17.926713326973925
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
ind = X_test.index
xlabel = df.loc[ind,'Date_Time'].to_numpy()
plt.figure(figsize=(12, 3))
plt.plot(xlabel,y_test.to_numpy(),c='black',label='True')
plt.plot(xlabel,pred,label='Predicted',c='red')
plt.legend(loc=1)
plt.title(f'Plot of forecast vs actual Seasonality in test set ({sp})',fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Seasonality Component')
plt.xlim((pd.Timestamp(2024,4,1),pd.Timestamp(2024,4,19)))
plt.tick_params('x',labelrotation=45)

# %%
# Save the figure
plt.savefig(f'/kaggle/working/{sp}.tiff', format='tiff', dpi=300, bbox_inches='tight')
plt.show()

# %%
best_params = study.best_params

# %%
best_params
# Out:
# {'lstm': 418, 'dropout': 0.2, 'lstm_2': 320, 'bs': 495}

# %% [markdown]
# # Append to Excel Function

# %%
def append_to_excel(file_path, data):
    try:
        # Load existing workbook or create a new one
        try:
            wb = load_workbook(file_path)
            ws = wb.active
        except FileNotFoundError:
            wb = Workbook()
            ws = wb.active
            ws.append(['sp',"All Years", 'lstm', 'dropout', 'lstm_2', 'bs', 'rmse', 'r2', 'mae', 'mape'])

        # Append data to the next available row
        ws.append(data)

        # Save the workbook
        wb.save(file_path)
        print("Data appended to Excel file successfully.")
    except Exception as e:
        print(f"Error: {e}")
lstm_value = best_params['lstm']
dropout_value = best_params['dropout']
lstm_2_value = best_params['lstm_2']
bs_value = best_params['bs']
            
# Append the data to the Excel file
data_to_append = [sp,"All Years", lstm_value, dropout_value, lstm_2_value, bs_value,rmse,rscore,mape,mae]
file_path = '/kaggle/working/Result.xlsx'
append_to_excel(file_path, data_to_append)
# Out:
# Data appended to Excel file successfully.

# %% [markdown]
# # 1st Jan 2022 to 1st June 2022

# %%
import pandas as pd
from feature_engine.timeseries.forecasting import LagFeatures

# Load the dataset
df = pd.read_csv('/kaggle/input/individual-seasonal-trend-residual-dataframes/df_seasonal.csv')

# Create lag features
lag_transformer = LagFeatures(variables=['Seasonal'], periods=[1, 2, 24, 24*7, 24*14, 24*21, 24*28])
df = lag_transformer.fit_transform(df)

# Drop rows with missing values after creating lag features
df = df.dropna()

# Create X (features) and y (target)
X = df.drop(columns=['Date_Time', 'Seasonal'])
y = df['Seasonal']

# X and y are now ready for modeling

# %%
df.head(3)
# Out:
#                Date_Time  Is_Holiday  Holiday_Type  OneHourSlot  Month  Year  \
# 672  2019-01-29 00:00:00           0             0            1      1  2019
# 673  2019-01-29 01:00:00           0             0            2      1  2019
# 674  2019-01-29 02:00:00           0             0            3      1  2019
#
#      Weekday   Seasonal  Seasonal_lag_1  Seasonal_lag_2  Seasonal_lag_24  \
# 672        1 -63.708124      -45.124924      -42.579945       -63.686455
# 673        1 -70.750910      -63.708124      -45.124924       -70.778905
# 674        1 -71.203272      -70.750910      -63.708124       -71.238425
#
#      Seasonal_lag_168  Seasonal_lag_336  Seasonal_lag_504  Seasonal_lag_672
# 672        -64.934960        -66.262929        -64.998123        -62.946317
# 673        -72.394609        -74.098984        -73.500706        -72.182077
# 674        -72.954441        -74.737855        -74.295151        -73.449614

# %%
X
# Out:
#        Is_Holiday  Holiday_Type  OneHourSlot  Month  Year  Weekday  \
# 672             0             0            1      1  2019        1
# 673             0             0            2      1  2019        1
# 674             0             0            3      1  2019        1
# 675             0             0            4      1  2019        1
# 676             0             0            5      1  2019        1
# ...           ...           ...          ...    ...   ...      ...
# 46459           0             0           20      4  2024        4
# 46460           0             0           21      4  2024        4
# 46461           0             0           22      4  2024        4
# 46462           0             0           23      4  2024        4
# 46463           0             0           24      4  2024        4
#
#        Seasonal_lag_1  Seasonal_lag_2  Seasonal_lag_24  Seasonal_lag_168  \
# 672        -45.124924      -42.579945       -63.686455        -64.934960
# 673        -63.708124      -45.124924       -70.778905        -72.394609
# 674        -70.750910      -63.708124       -71.238425        -72.954441
# 675        -71.203272      -70.750910       -71.236869        -72.940186
# 676        -71.204769      -71.203272       -67.898137        -69.263391
# ...               ...             ...              ...               ...
# 46459        3.135115       26.843958       -11.486903         -1.718593
# 46460      -13.215410        3.135115        24.160515         18.796946
# 46461       24.998571      -13.215410       -23.116244        -23.451170
# 46462      -22.917023       24.998571       -19.667309        -27.486975
# 46463      -18.455391      -22.917023       -23.596726        -20.591160
#
#        Seasonal_lag_336  Seasonal_lag_504  Seasonal_lag_672
# 672          -66.262929        -64.998123        -62.946317
# 673          -74.098984        -73.500706        -72.182077
# 674          -74.737855        -74.295151        -73.449614
# 675          -74.733035        -74.311972        -73.517630
# 676          -70.243634        -69.075519        -67.510447
# ...                 ...               ...               ...
# 46459         10.341876         18.431855         22.763349
# 46460         15.932651          7.417508          4.404355
# 46461        -22.175281        -21.882550        -21.805520
# 46462        -35.011246        -31.377569        -24.176137
# 46463        -20.981346        -29.102374        -30.969258
#
# [45792 rows x 13 columns]

# %%
y
# Out:
# 672     -63.708124
# 673     -70.750910
# 674     -71.203272
# 675     -71.204769
# 676     -67.921373
#            ...
# 46459   -13.215410
# 46460    24.998571
# 46461   -22.917023
# 46462   -18.455391
# 46463   -24.138317
# Name: Seasonal, Length: 45792, dtype: float64

# %%
# Ensure Date_Time is converted to datetime format
df['Date_Time'] = pd.to_datetime(df['Date_Time'])

# Filter the DataFrame for the specified date range
temp = df[(df['Date_Time'] >= pd.Timestamp(2022, 1, 1)) & (df['Date_Time'] < pd.Timestamp(2022, 6, 1))]

# Check if the sum of 'Seasonal' is 0
if temp['Seasonal'].sum() == 0:
    # Split into train & test (95% for train and 5% for test)
    X_train = X.iloc[:int(np.round((0.95 * len(X)))), :]
    X_test = X.iloc[int(np.round((0.95 * len(X)))):, :]
    y_train = y[:int(np.round((0.95 * len(X))))]
    y_test = y[int(np.round((0.95 * len(X)))):]
else:
    # Split into train & test (80% for train and 20% for test)
    X_train = X.iloc[:int(np.round((0.8 * len(X)))), :]
    X_test = X.iloc[int(np.round((0.8 * len(X)))):, :]
    y_train = y[:int(np.round((0.8 * len(X))))]
    y_test = y[int(np.round((0.8 * len(X)))):]

# %%
# normalizing train set & reshape
sc_X = MinMaxScaler(feature_range = (0, 1))
X_train_scaled = sc_X.fit_transform(X_train)
X_train_scaled_2 = np.reshape(X_train_scaled,(X_train_scaled.shape[0],X_train_scaled.shape[1],1))

sc_y = MinMaxScaler(feature_range = (0, 1))
y_train_scaled = sc_y.fit_transform(np.reshape(y_train,(len(y_train),1)))


# normalizing test set & reshape
X_test_scaled = sc_X.transform(X_test)
X_test_scaled_2 = np.reshape(X_test_scaled,(X_test_scaled.shape[0],X_test_scaled.shape[1],1))

# %%
model = tf.keras.models.load_model(f'/kaggle/working/Voltas_Gate_Thane_Station_West.keras')
pred_inverse = model.predict(X_test_scaled_2)
pred_2 = sc_y.inverse_transform(pred_inverse)
pred = np.floor(pred_2)

output = pd.DataFrame()
output = pd.concat([output,X_test],ignore_index=True)
output['Pred'] = pred
output['Actual'] = y_test.to_numpy()
output.to_csv(f'/kaggle/working/{sp}.csv')
# Out:
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# # 20th april 2024 to 7th May 2024 11:00PM

# %%
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')


# Load the data
check = pd.read_csv(f'/kaggle/working/input_file_1.csv')

# Create a date range and ensure it matches the length of the DataFrame
date_range = pd.date_range('2024-04-20 00:00', pd.Timestamp(2024, 5, 7, 23), freq='1H')
if len(date_range) != check.shape[0]:
    # Align the lengths by either truncating or extending the DataFrame
    if len(date_range) < check.shape[0]:
        check = check.iloc[:len(date_range)]
    else:
        additional_rows = pd.DataFrame({
           # 'Station_Pair': [sp] * (len(date_range) - check.shape[0]),
            'Date_Time': [pd.NaT] * (len(date_range) - check.shape[0]),
            'Seasonal': [0] * (len(date_range) - check.shape[0])
        })
        check = pd.concat([check, additional_rows], ignore_index=True)

# Assign the date range to the Date_Time column
check['Date_Time'] = date_range

# Define a custom function to create lag features
def create_lag_features(df, lag_vars, lags):
    for var in lag_vars:
        for lag in lags:
            df[f'{var}_lag_{lag}'] = df[var].shift(lag)
    return df

forecast_df = check.copy()
forecast_df['Seasonal'] = 0
ref_date = forecast_df['Date_Time'].iloc[0] - pd.Timedelta(days=400)
temp = df[(df['Date_Time'] >= ref_date)]
combined_df = pd.concat([temp, forecast_df], ignore_index=True)
index_start = combined_df[combined_df['Date_Time'] >= pd.Timestamp(2024, 4, 20)].index[0]
num_of_forecast = forecast_df.shape[0]

for index in range(num_of_forecast):
    temp = combined_df.loc[:index_start]

    # create lag features
    temp = create_lag_features(temp, lag_vars=['Seasonal'], lags=[1, 2, 24, 24*7, 24*14, 24*21, 24*28])
    temp.dropna(inplace=True)

    # create X
    X = temp.drop(columns=['Date_Time','Seasonal','OneHourSlot'])

    # normalizing test set & reshape
    sc_X = joblib.load(f'/kaggle/working/scaler_X_{sp}.joblib')
    X_scaled = sc_X.transform(X)
    X_scaled_2 = np.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

    # predict on test set
    model = tf.keras.models.load_model(f'/kaggle/working/{sp}.keras')
    pred_inverse = model.predict(X_scaled_2[-1, :, :].T)
    sc_y = joblib.load(f'/kaggle/working/scaler_y_{sp}.joblib')
    pred_2 = sc_y.inverse_transform(pred_inverse)
    pred = np.floor(pred_2)
    pred = np.where(pred < 0, 0, pred)
    combined_df.loc[index_start, 'Seasonal'] = pred[0][0]
    index_start += 1

combined_df[combined_df['Date_Time'] >= pd.Timestamp(2024, 4, 20)].to_csv(f'/kaggle/working/forecast_{sp}.csv')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step

# %%
# Load predictions
file1 = pd.read_csv(f"/kaggle/working/Voltas_Gate_Thane_Station_West.csv")
pred = file1['Pred']
pred = np.where(pred < 0, 0, pred)

# Load the model for training predictions
model = tf.keras.models.load_model(f'/kaggle/working/{sp}.keras')
train_pred_inverse = model.predict(X_train_scaled_2)
train_pred_2 = sc_y.inverse_transform(train_pred_inverse)
train_pred = np.floor(train_pred_2)
train_pred = np.where(train_pred < 0, 0, train_pred)

# Load the forecast
forecast = pd.read_csv(f'/kaggle/working/forecast_{sp}.csv')
forecast['Date_Time'] = pd.date_range(pd.Timestamp(2024, 4, 20, 0, 0), pd.Timestamp(2024, 5, 7, 23, 0), freq='1H')

# Plot the results
plt.plot(df['Date_Time'].to_numpy(), df['Seasonal'].to_numpy(), c='black', label='Actual')
plt.plot(df.loc[X_train.index, 'Date_Time'].to_numpy(), train_pred, c='blue', label='Train', alpha=0.6)
plt.plot(df.loc[X_test.index, 'Date_Time'].to_numpy(), pred, c='green', label='Test', alpha=0.6)
plt.plot(forecast['Date_Time'].to_numpy(), forecast['Seasonal'], c='orange', label='Forecast', alpha=0.6)

plt.legend(loc=0)
plt.title(f'Plot of forecast vs actual passengers in train, test, forecast set ({sp})', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Seasonality')
plt.savefig(f'/kaggle/working/{sp}.tiff', format='tiff', dpi=300, bbox_inches='tight')
# Out:
# 1145/1145 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
