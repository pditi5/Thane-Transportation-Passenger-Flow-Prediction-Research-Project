# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('/content/2018_route6.csv',encoding='utf-8')
df1
# Out:
#              id  RouteNumber  TripDirection  SourceId   SourceName  \
# 0       1422656            6              0        20   वागळे आगार
# 1       1422657            6              0        20   वागळे आगार
# 2       1422658            6              0        20   वागळे आगार
# 3       1422660            6              0        20   वागळे आगार
# 4       1422661            6              0        20   वागळे आगार
# ...         ...          ...            ...       ...          ...
# 100382  2350335            6              1        17  ठाणे स्टेशन
# 100383  2350337            6              1        17  ठाणे स्टेशन
# 100384  2350385            6              1        17  ठाणे स्टेशन
# 100385  2350388            6              1        17  ठाणे स्टेशन
# 100386  2350396            6              1        17  ठाणे स्टेशन
#
#         DestinationID  DestinationName issueDate
# 0                  17      ठाणे स्टेशन   27:44.0
# 1                  17      ठाणे स्टेशन   28:06.0
# ...

# %%
df2=pd.read_csv('/content/2019_route6.csv', encoding='utf-8')
df2
# Out:
#               id  RouteNumber  TripDirection  SourceId        SourceName  \
# 0       20681683          6.0            0.0      17.0       ठाणे स्टेशन
# 1       20681689          6.0            0.0      17.0       ठाणे स्टेशन
# 2       20681690          6.0            0.0      17.0       ठाणे स्टेशन
# 3       20681691          6.0            0.0      17.0       ठाणे स्टेशन
# 4       20681762          6.0            0.0      17.0       ठाणे स्टेशन
# ...          ...          ...            ...       ...               ...
# 111271  23279522          6.0            0.0      15.0        वृदावन सो.
# 111272  23279658          6.0            0.0      15.0        वृदावन सो.
# 111273  23279693          6.0            0.0      15.0        वृदावन सो.
# 111274  23279839          6.0            0.0      16.0  सिव्हील / कोर्ट
# 111275  23280003          NaN            NaN       NaN               NaN
#
#         DestinationID  DestinationName issueDate
# ...

# %%
df3=pd.read_csv('/content/2020_route6.csv', encoding='utf-8')
df3
# Out:
#               id  RouteNumber  TripDirection  SourceId       SourceName  \
# 0       79119885            6              0        17      ठाणे स्टेशन
# 1       79119952            6              0        17      ठाणे स्टेशन
# 2       79119969            6              0        17      ठाणे स्टेशन
# 3       79119970            6              0        17      ठाणे स्टेशन
# 4       79120035            6              0        17      ठाणे स्टेशन
# ...          ...          ...            ...       ...              ...
# 122014  81832147            6              1        19  कामगार हौस्पीटल
# 122015  81832190            6              1        19  कामगार हौस्पीटल
# 122016  81832218            6              1        19  कामगार हौस्पीटल
# 122017  81832247            6              1        19  कामगार हौस्पीटल
# 122018  81832274            6              1        19  कामगार हौस्पीटल
#
#         DestinationID  DestinationName issueDate
# 0                  18   प्रदीप सोसायटी   21:04.0
# ...

# %%
df4=pd.read_csv('/content/2021_route6.csv',encoding='utf-8')
df4
# Out:
#                id  RouteNumber  TripDirection  SourceId   SourceName  \
# 0       101721951          6.0            0.0      17.0  ठाणे स्टेशन
# 1       101721952          6.0            0.0      17.0  ठाणे स्टेशन
# 2       101721953          6.0            0.0      17.0  ठाणे स्टेशन
# 3       101721954          6.0            0.0      17.0  ठाणे स्टेशन
# 4       101721955          6.0            0.0      17.0  ठाणे स्टेशन
# ...           ...          ...            ...       ...          ...
# 217351  108082795          6.0            0.0      17.0  ठाणे स्टेशन
# 217352  108082800          6.0            0.0      17.0  ठाणे स्टेशन
# 217353  108082816          6.0            0.0      17.0  ठाणे स्टेशन
# 217354  108082821          6.0            0.0      17.0  ठाणे स्टेशन
# 217355          1          NaN            NaN       NaN          NaN
#
#         DestinationID  DestinationName issueDate
# 0                20.0       वागळे आगार   00:39.0
# ...

# %%
df5=pd.read_csv('/content/2022_route6.csv',encoding='utf-8')
df5
# Out:
#                id  RouteNumber  TripDirection  SourceId      SourceName  \
# 0       136993652            6              0        17     ठाणे स्टेशन
# 1       136993653            6              0        17     ठाणे स्टेशन
# 2       136993898            6              0        18  प्रदीप सोसायटी
# 3       136992277            6              0        17     ठाणे स्टेशन
# 4       136992278            6              0        17     ठाणे स्टेशन
# ...           ...          ...            ...       ...             ...
# 336880  144713676            6              0        17     ठाणे स्टेशन
# 336881  144713677            6              0        17     ठाणे स्टेशन
# 336882  144713678            6              0        17     ठाणे स्टेशन
# 336883  144713679            6              1        20      वागळे आगार
# 336884  144713680            6              1        20      वागळे आगार
#
#         DestinationID  DestinationName issueDate
# 0                  19  कामगार हौस्पीटल   16:33.0
# ...

# %%
df6=pd.read_csv('/content/2023_route6.csv' ,encoding='utf-8')
df6
# Out:
#                id  RouteNumber  TripDirection  SourceId       SourceName  \
# 0       191524552            6              0        18   प्रदीप सोसायटी
# 1       191524553            6              0        18   प्रदीप सोसायटी
# 2       191529562            6              0        18   प्रदीप सोसायटी
# 3       191528438            6              0        17      ठाणे स्टेशन
# 4       191528439            6              0        17      ठाणे स्टेशन
# ...           ...          ...            ...       ...              ...
# 554101  206383715            6              1        19  कामगार हौस्पीटल
# 554102  206383716            6              1        19  कामगार हौस्पीटल
# 554103  206383717            6              1        19  कामगार हौस्पीटल
# 554104  206383718            6              1        19  कामगार हौस्पीटल
# 554105  206383719            6              1        19        कामगार हौ
#
#         DestinationID  DestinationName issueDate
# ...

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
ref_date1 = datetime(2018, 1, 1)
df1['datetime'] = df1['issueDate'].apply(lambda x: ref_date1 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date1)
df1
# Out:
#              id  RouteNumber  TripDirection  SourceId   SourceName  \
# 0       1422656            6              0        20   वागळे आगार
# 1       1422657            6              0        20   वागळे आगार
# 2       1422658            6              0        20   वागळे आगार
# 3       1422660            6              0        20   वागळे आगार
# 4       1422661            6              0        20   वागळे आगार
# ...         ...          ...            ...       ...          ...
# 100382  2350335            6              1        17  ठाणे स्टेशन
# 100383  2350337            6              1        17  ठाणे स्टेशन
# 100384  2350385            6              1        17  ठाणे स्टेशन
# 100385  2350388            6              1        17  ठाणे स्टेशन
# 100386  2350396            6              1        17  ठाणे स्टेशन
#
#         DestinationID  DestinationName issueDate            datetime
# 0                  17      ठाणे स्टेशन   27:44.0 2018-01-01 03:44:00
# ...

# %%
ref_date2 = datetime(2019, 1, 1)
df2['datetime'] = df2['issueDate'].apply(lambda x: ref_date2 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date2)
df2
# Out:
#               id  RouteNumber  TripDirection  SourceId        SourceName  \
# 0       20681683          6.0            0.0      17.0       ठाणे स्टेशन
# 1       20681689          6.0            0.0      17.0       ठाणे स्टेशन
# 2       20681690          6.0            0.0      17.0       ठाणे स्टेशन
# 3       20681691          6.0            0.0      17.0       ठाणे स्टेशन
# 4       20681762          6.0            0.0      17.0       ठाणे स्टेशन
# ...          ...          ...            ...       ...               ...
# 111271  23279522          6.0            0.0      15.0        वृदावन सो.
# 111272  23279658          6.0            0.0      15.0        वृदावन सो.
# 111273  23279693          6.0            0.0      15.0        वृदावन सो.
# 111274  23279839          6.0            0.0      16.0  सिव्हील / कोर्ट
# 111275  23280003          NaN            NaN       NaN               NaN
#
#         DestinationID  DestinationName issueDate            datetime
# ...

# %%
ref_date3 = datetime(2020, 1, 1)
df3['datetime'] = df3['issueDate'].apply(lambda x: ref_date3 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date3)

ref_date4 = datetime(2021, 1, 1)
df4['datetime'] = df4['issueDate'].apply(lambda x: ref_date4 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date4)

ref_date5 = datetime(2022, 1, 1)
df5['datetime'] = df5['issueDate'].apply(lambda x: ref_date5 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date4)

ref_date6 = datetime(2023, 1, 1)
df6['datetime'] = df6['issueDate'].apply(lambda x: ref_date6 + timedelta(hours=int(x.split(':')[0]) % 24, minutes=int(x.split(':')[1].split('.')[0]), seconds=int(x.split('.')[1])) if isinstance(x, str) else ref_date4)

# %%
merged_df = pd.concat([df1, df2, df3, df4, df5, df6], axis=0)
merged_df
# Out:
#                id  RouteNumber  TripDirection  SourceId       SourceName  \
# 0         1422656          6.0            0.0      20.0       वागळे आगार
# 1         1422657          6.0            0.0      20.0       वागळे आगार
# 2         1422658          6.0            0.0      20.0       वागळे आगार
# 3         1422660          6.0            0.0      20.0       वागळे आगार
# 4         1422661          6.0            0.0      20.0       वागळे आगार
# ...           ...          ...            ...       ...              ...
# 554101  206383715          6.0            1.0      19.0  कामगार हौस्पीटल
# 554102  206383716          6.0            1.0      19.0  कामगार हौस्पीटल
# 554103  206383717          6.0            1.0      19.0  कामगार हौस्पीटल
# 554104  206383718          6.0            1.0      19.0  कामगार हौस्पीटल
# 554105  206383719          6.0            1.0      19.0        कामगार हौ
#
#         DestinationID DestinationName issueDate            datetime
# ...

# %%
# Save merged dataframe to CSV file in Google Drive
merged_df.to_csv('/content/merged_data.csv', index=False)

# %%
df=merged_df

# %% [markdown]
# Convert Marathi to English Source-Destinations

# %%
marathi_to_english = {
    'वृदावन सो.': 'Vrindavan Society',
    'राबोडी': 'Rabodi',
    'श्रीरंग सोसा.': 'Shrirang Society',
    'केîव्हीला': 'K villa',
    'पोलीस लाईन': 'Police Line',
    'सिव्हील / कोर्ट': 'Court Naka',
    'जांभ ळीनाका': 'Jambhali Naka',
    'प्रभात सिनेमा': 'Prabhat Cinema',
    'ठाणे स्टेशन': 'Thane Station(Satis)',
    'गांवदेवी': 'Gaondevi Mandir',
    'आईस फैक्टरी': 'Ice Factory',
    'हरी निवास': 'Hari Nivas',
    'प्रदीप सोसायटी': 'Pradeep Society/Panch Pakhadi',
    'परमार्थ निकेतन': 'Parmarth Niketan',
    'मनपा.भवन': 'Manpa Bhavan',
    'नामदेववाडी': 'Namdev Wadi',
    'नितीन कंपनी': 'Nitin Company Circle',
    'रामचंद्रनगर 1': 'Ramachandra Nagar 1',
    'वैतीवाडी': 'Vaiti Wadi',
    'ज्ञानेश्वरनगर': 'Dyaneshwar Nagar',
    'कामगार हौस्पीटल': 'Kamgar Gate',
    'सावरकर नाका': 'Savarkar Naka',
    'इंदिरानगर': 'Indira Nagar',
    'जोस्ट वसाहत': 'Jost Colony',
    'साठेनगर': 'Sathe Nagar Thane',
    'वागळे आगार': 'Wagle Depot'
}

# %%
df['SourceName'] = df['SourceName'].str.strip().map(marathi_to_english)
df['DestinationName'] = df['DestinationName'].str.strip().map(marathi_to_english)

# %%
df.head()
# Out:
#         id  RouteNumber  TripDirection  SourceId   SourceName  DestinationID  \
# 0  1422656          6.0            0.0      20.0  Wagle Depot           17.0
# 1  1422657          6.0            0.0      20.0  Wagle Depot           17.0
# 2  1422658          6.0            0.0      20.0  Wagle Depot           17.0
# 3  1422660          6.0            0.0      20.0  Wagle Depot           17.0
# 4  1422661          6.0            0.0      20.0  Wagle Depot           17.0
#
#         DestinationName issueDate            datetime
# 0  Thane Station(Satis)   27:44.0 2018-01-01 03:44:00
# 1  Thane Station(Satis)   28:06.0 2018-01-01 04:06:00
# 2  Thane Station(Satis)   28:42.0 2018-01-01 04:42:00
# 3  Thane Station(Satis)   28:57.0 2018-01-01 04:57:00
# 4  Thane Station(Satis)   29:21.0 2018-01-01 05:21:00

# %%
source_destination_df=df[['SourceName', 'DestinationName']]
source_destination_df
# Out:
#          SourceName       DestinationName
# 0       Wagle Depot  Thane Station(Satis)
# 1       Wagle Depot  Thane Station(Satis)
# 2       Wagle Depot  Thane Station(Satis)
# 3       Wagle Depot  Thane Station(Satis)
# 4       Wagle Depot  Thane Station(Satis)
# ...             ...                   ...
# 554101  Kamgar Gate  Thane Station(Satis)
# 554102  Kamgar Gate  Thane Station(Satis)
# 554103  Kamgar Gate  Thane Station(Satis)
# 554104  Kamgar Gate  Thane Station(Satis)
# 554105          NaN                   NaN
#
# [1442029 rows x 2 columns]

# %%
source_destination_df=source_destination_df.fillna('')

# %%
null_values=source_destination_df[source_destination_df.isnull().any(axis=1)]
print(null_values)
# Out:
# Empty DataFrame
# Columns: [SourceName, DestinationName]
# Index: []

# %% [markdown]
# # total number of unique source-destination pairs

# %%
df['source_destination']=df['SourceName'] + "->" + df['DestinationName']
unique_pairs=df['source_destination'].unique()
print("Total Number of Unique Source - Destination Pairs : " ,len(unique_pairs)), unique_pairs
# Out:
# Total Number of Unique Source - Destination Pairs :  33
# (None,
#  array(['Wagle Depot->Thane Station(Satis)',
#         'Wagle Depot->Pradeep Society/Panch Pakhadi',
#         'Kamgar Gate->Thane Station(Satis)',
#         'Kamgar Gate->Pradeep Society/Panch Pakhadi',
#         'Pradeep Society/Panch Pakhadi->Thane Station(Satis)',
#         'Pradeep Society/Panch Pakhadi->Court Naka',
#         'Pradeep Society/Panch Pakhadi->Vrindavan Society',
#         'Thane Station(Satis)->Vrindavan Society',
#         'Thane Station(Satis)->Court Naka', 'Wagle Depot->Kamgar Gate',
#         'Vrindavan Society->Wagle Depot',
#         'Thane Station(Satis)->Wagle Depot',
#         'Thane Station(Satis)->Kamgar Gate',
#         'Thane Station(Satis)->Pradeep Society/Panch Pakhadi',
#         'Pradeep Society/Panch Pakhadi->Wagle Depot',
#         'Wagle Depot->Court Naka', 'Court Naka->Vrindavan Society',
#         'Vrindavan Society->Thane Station(Satis)',
# ...

# %% [markdown]
# # inserting a holiday column

# %%
df.head()
# Out:
#         id  RouteNumber  TripDirection  SourceId   SourceName  DestinationID  \
# 0  1422656          6.0            0.0      20.0  Wagle Depot           17.0
# 1  1422657          6.0            0.0      20.0  Wagle Depot           17.0
# 2  1422658          6.0            0.0      20.0  Wagle Depot           17.0
# 3  1422660          6.0            0.0      20.0  Wagle Depot           17.0
# 4  1422661          6.0            0.0      20.0  Wagle Depot           17.0
#
#         DestinationName issueDate            datetime  \
# 0  Thane Station(Satis)   27:44.0 2018-01-01 03:44:00
# 1  Thane Station(Satis)   28:06.0 2018-01-01 04:06:00
# 2  Thane Station(Satis)   28:42.0 2018-01-01 04:42:00
# 3  Thane Station(Satis)   28:57.0 2018-01-01 04:57:00
# 4  Thane Station(Satis)   29:21.0 2018-01-01 05:21:00
#
#                   source_destination
# 0  Wagle Depot->Thane Station(Satis)
# 1  Wagle Depot->Thane Station(Satis)
# 2  Wagle Depot->Thane Station(Satis)
# ...

# %%
# Convert 'Date_Time' column to datetime
df['datetime'] = pd.to_datetime(df['datetime'])
